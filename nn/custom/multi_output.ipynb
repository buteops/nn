# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 934us/sample - loss: 247.0020 - y1_output_loss: 115.2519 - y2_output_loss: 129.4040 - y1_output_root_mean_squared_error: 10.7870 - y2_output_root_mean_squared_error: 11.4299 - val_loss: 31.7762 - val_y1_output_loss: 13.3028 - val_y2_output_loss: 17.4780 - val_y1_output_root_mean_squared_error: 3.7123 - val_y2_output_root_mean_squared_error: 4.2421
# Epoch 2/500
# 614/614 [==============================] - 0s 141us/sample - loss: 30.8370 - y1_output_loss: 12.7693 - y2_output_loss: 17.9741 - y1_output_root_mean_squared_error: 3.5758 - y2_output_root_mean_squared_error: 4.2486 - val_loss: 20.0299 - val_y1_output_loss: 9.1190 - val_y2_output_loss: 10.9863 - val_y1_output_root_mean_squared_error: 3.0017 - val_y2_output_root_mean_squared_error: 3.3196
# Epoch 3/500
# 614/614 [==============================] - 0s 138us/sample - loss: 25.8681 - y1_output_loss: 9.9710 - y2_output_loss: 15.7904 - y1_output_root_mean_squared_error: 3.1616 - y2_output_root_mean_squared_error: 3.9840 - val_loss: 24.6997 - val_y1_output_loss: 12.4806 - val_y2_output_loss: 12.3042 - val_y1_output_root_mean_squared_error: 3.5086 - val_y2_output_root_mean_squared_error: 3.5199
# Epoch 4/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.1921 - y1_output_loss: 9.3474 - y2_output_loss: 13.9225 - y1_output_root_mean_squared_error: 3.0476 - y2_output_root_mean_squared_error: 3.7288 - val_loss: 31.0699 - val_y1_output_loss: 8.4372 - val_y2_output_loss: 21.8950 - val_y1_output_root_mean_squared_error: 2.9260 - val_y2_output_root_mean_squared_error: 4.7443
# Epoch 5/500
# 614/614 [==============================] - 0s 138us/sample - loss: 25.1498 - y1_output_loss: 9.5873 - y2_output_loss: 15.3767 - y1_output_root_mean_squared_error: 3.1088 - y2_output_root_mean_squared_error: 3.9351 - val_loss: 16.3012 - val_y1_output_loss: 7.5176 - val_y2_output_loss: 8.8257 - val_y1_output_root_mean_squared_error: 2.7071 - val_y2_output_root_mean_squared_error: 2.9955
# Epoch 6/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.2103 - y1_output_loss: 8.8223 - y2_output_loss: 13.4207 - y1_output_root_mean_squared_error: 2.9692 - y2_output_root_mean_squared_error: 3.6598 - val_loss: 32.4189 - val_y1_output_loss: 12.4203 - val_y2_output_loss: 20.9369 - val_y1_output_root_mean_squared_error: 3.4433 - val_y2_output_root_mean_squared_error: 4.5346
# Epoch 7/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.3958 - y1_output_loss: 8.4388 - y2_output_loss: 13.8369 - y1_output_root_mean_squared_error: 2.9144 - y2_output_root_mean_squared_error: 3.7286 - val_loss: 20.0012 - val_y1_output_loss: 7.6690 - val_y2_output_loss: 11.9936 - val_y1_output_root_mean_squared_error: 2.7599 - val_y2_output_root_mean_squared_error: 3.5191
# Epoch 8/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.9802 - y1_output_loss: 9.1043 - y2_output_loss: 15.9708 - y1_output_root_mean_squared_error: 3.0123 - y2_output_root_mean_squared_error: 3.9882 - val_loss: 28.2598 - val_y1_output_loss: 8.8666 - val_y2_output_loss: 18.8248 - val_y1_output_root_mean_squared_error: 2.9679 - val_y2_output_root_mean_squared_error: 4.4104
# Epoch 9/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.7253 - y1_output_loss: 8.4904 - y2_output_loss: 14.6505 - y1_output_root_mean_squared_error: 2.8940 - y2_output_root_mean_squared_error: 3.7882 - val_loss: 73.8984 - val_y1_output_loss: 16.0432 - val_y2_output_loss: 56.1298 - val_y1_output_root_mean_squared_error: 4.0568 - val_y2_output_root_mean_squared_error: 7.5790
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.5164 - y1_output_loss: 7.9802 - y2_output_loss: 13.4850 - y1_output_root_mean_squared_error: 2.8230 - y2_output_root_mean_squared_error: 3.6806 - val_loss: 19.7535 - val_y1_output_loss: 9.2907 - val_y2_output_loss: 11.6848 - val_y1_output_root_mean_squared_error: 2.9162 - val_y2_output_root_mean_squared_error: 3.3540
# Epoch 11/500
# 614/614 [==============================] - 0s 151us/sample - loss: 21.9154 - y1_output_loss: 8.0749 - y2_output_loss: 13.7443 - y1_output_root_mean_squared_error: 2.8458 - y2_output_root_mean_squared_error: 3.7171 - val_loss: 15.2082 - val_y1_output_loss: 6.8725 - val_y2_output_loss: 8.5331 - val_y1_output_root_mean_squared_error: 2.5746 - val_y2_output_root_mean_squared_error: 2.9291
# Epoch 12/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.8860 - y1_output_loss: 6.8843 - y2_output_loss: 10.8985 - y1_output_root_mean_squared_error: 2.6284 - y2_output_root_mean_squared_error: 3.3133 - val_loss: 18.4308 - val_y1_output_loss: 8.5810 - val_y2_output_loss: 10.6032 - val_y1_output_root_mean_squared_error: 2.8316 - val_y2_output_root_mean_squared_error: 3.2269
# Epoch 13/500
# 614/614 [==============================] - 0s 139us/sample - loss: 19.0871 - y1_output_loss: 7.3365 - y2_output_loss: 11.6890 - y1_output_root_mean_squared_error: 2.7088 - y2_output_root_mean_squared_error: 3.4278 - val_loss: 20.1464 - val_y1_output_loss: 11.5566 - val_y2_output_loss: 9.2094 - val_y1_output_root_mean_squared_error: 3.3127 - val_y2_output_root_mean_squared_error: 3.0286
# Epoch 14/500
# 614/614 [==============================] - 0s 142us/sample - loss: 21.5064 - y1_output_loss: 7.9527 - y2_output_loss: 13.5952 - y1_output_root_mean_squared_error: 2.8073 - y2_output_root_mean_squared_error: 3.6912 - val_loss: 17.0553 - val_y1_output_loss: 7.2780 - val_y2_output_loss: 9.8625 - val_y1_output_root_mean_squared_error: 2.6653 - val_y2_output_root_mean_squared_error: 3.1546
# Epoch 15/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.5394 - y1_output_loss: 6.3993 - y2_output_loss: 10.0576 - y1_output_root_mean_squared_error: 2.5360 - y2_output_root_mean_squared_error: 3.1794 - val_loss: 14.4659 - val_y1_output_loss: 6.5516 - val_y2_output_loss: 8.4233 - val_y1_output_root_mean_squared_error: 2.4829 - val_y2_output_root_mean_squared_error: 2.8812
# Epoch 16/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.4193 - y1_output_loss: 5.7730 - y2_output_loss: 9.5380 - y1_output_root_mean_squared_error: 2.4098 - y2_output_root_mean_squared_error: 3.1003 - val_loss: 20.2959 - val_y1_output_loss: 11.1905 - val_y2_output_loss: 9.6758 - val_y1_output_root_mean_squared_error: 3.2645 - val_y2_output_root_mean_squared_error: 3.1047
# Epoch 17/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.9838 - y1_output_loss: 5.5030 - y2_output_loss: 8.4542 - y1_output_root_mean_squared_error: 2.3530 - y2_output_root_mean_squared_error: 2.9064 - val_loss: 26.8460 - val_y1_output_loss: 9.2377 - val_y2_output_loss: 18.8142 - val_y1_output_root_mean_squared_error: 2.9242 - val_y2_output_root_mean_squared_error: 4.2773
# Epoch 18/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.8923 - y1_output_loss: 5.6393 - y2_output_loss: 8.2835 - y1_output_root_mean_squared_error: 2.3720 - y2_output_root_mean_squared_error: 2.8750 - val_loss: 23.5600 - val_y1_output_loss: 10.3165 - val_y2_output_loss: 14.1703 - val_y1_output_root_mean_squared_error: 3.1097 - val_y2_output_root_mean_squared_error: 3.7269
# Epoch 19/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.3551 - y1_output_loss: 5.3886 - y2_output_loss: 8.9839 - y1_output_root_mean_squared_error: 2.3104 - y2_output_root_mean_squared_error: 3.0028 - val_loss: 27.4733 - val_y1_output_loss: 9.1604 - val_y2_output_loss: 17.7597 - val_y1_output_root_mean_squared_error: 3.0279 - val_y2_output_root_mean_squared_error: 4.2784
# Epoch 20/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.7523 - y1_output_loss: 5.0476 - y2_output_loss: 8.6101 - y1_output_root_mean_squared_error: 2.2547 - y2_output_root_mean_squared_error: 2.9442 - val_loss: 15.3616 - val_y1_output_loss: 5.8314 - val_y2_output_loss: 9.7959 - val_y1_output_root_mean_squared_error: 2.3581 - val_y2_output_root_mean_squared_error: 3.1307
# Epoch 21/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.1335 - y1_output_loss: 5.3074 - y2_output_loss: 9.8218 - y1_output_root_mean_squared_error: 2.3129 - y2_output_root_mean_squared_error: 3.1279 - val_loss: 13.6993 - val_y1_output_loss: 6.2005 - val_y2_output_loss: 8.0017 - val_y1_output_root_mean_squared_error: 2.4076 - val_y2_output_root_mean_squared_error: 2.8112
# Epoch 22/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.4255 - y1_output_loss: 4.5772 - y2_output_loss: 7.7625 - y1_output_root_mean_squared_error: 2.1476 - y2_output_root_mean_squared_error: 2.7952 - val_loss: 28.1748 - val_y1_output_loss: 11.1411 - val_y2_output_loss: 16.4845 - val_y1_output_root_mean_squared_error: 3.3631 - val_y2_output_root_mean_squared_error: 4.1067
# Epoch 23/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.6046 - y1_output_loss: 4.5015 - y2_output_loss: 7.0109 - y1_output_root_mean_squared_error: 2.1300 - y2_output_root_mean_squared_error: 2.6585 - val_loss: 19.6158 - val_y1_output_loss: 6.4649 - val_y2_output_loss: 13.4270 - val_y1_output_root_mean_squared_error: 2.4968 - val_y2_output_root_mean_squared_error: 3.6581
# Epoch 24/500
# 614/614 [==============================] - 0s 144us/sample - loss: 11.8142 - y1_output_loss: 4.3312 - y2_output_loss: 7.4487 - y1_output_root_mean_squared_error: 2.0753 - y2_output_root_mean_squared_error: 2.7400 - val_loss: 13.0825 - val_y1_output_loss: 5.5953 - val_y2_output_loss: 8.0301 - val_y1_output_root_mean_squared_error: 2.2883 - val_y2_output_root_mean_squared_error: 2.8011
# Epoch 25/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.1183 - y1_output_loss: 3.8603 - y2_output_loss: 6.2377 - y1_output_root_mean_squared_error: 1.9625 - y2_output_root_mean_squared_error: 2.5034 - val_loss: 15.9583 - val_y1_output_loss: 5.9771 - val_y2_output_loss: 10.5120 - val_y1_output_root_mean_squared_error: 2.3672 - val_y2_output_root_mean_squared_error: 3.2179
# Epoch 26/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.5393 - y1_output_loss: 3.7554 - y2_output_loss: 6.8208 - y1_output_root_mean_squared_error: 1.9400 - y2_output_root_mean_squared_error: 2.6030 - val_loss: 22.6139 - val_y1_output_loss: 7.0061 - val_y2_output_loss: 16.2263 - val_y1_output_root_mean_squared_error: 2.5674 - val_y2_output_root_mean_squared_error: 4.0028
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.5466 - y1_output_loss: 4.1003 - y2_output_loss: 7.5601 - y1_output_root_mean_squared_error: 2.0148 - y2_output_root_mean_squared_error: 2.7363 - val_loss: 13.1240 - val_y1_output_loss: 5.3877 - val_y2_output_loss: 7.7055 - val_y1_output_root_mean_squared_error: 2.2882 - val_y2_output_root_mean_squared_error: 2.8085
# Epoch 28/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.9193 - y1_output_loss: 3.8562 - y2_output_loss: 6.9940 - y1_output_root_mean_squared_error: 1.9698 - y2_output_root_mean_squared_error: 2.6532 - val_loss: 13.1952 - val_y1_output_loss: 5.3023 - val_y2_output_loss: 8.0793 - val_y1_output_root_mean_squared_error: 2.2540 - val_y2_output_root_mean_squared_error: 2.8487
# Epoch 29/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.8301 - y1_output_loss: 3.2804 - y2_output_loss: 5.4898 - y1_output_root_mean_squared_error: 1.8153 - y2_output_root_mean_squared_error: 2.3526 - val_loss: 13.4405 - val_y1_output_loss: 5.2199 - val_y2_output_loss: 8.1539 - val_y1_output_root_mean_squared_error: 2.2623 - val_y2_output_root_mean_squared_error: 2.8849
# Epoch 30/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.7082 - y1_output_loss: 3.6680 - y2_output_loss: 6.9457 - y1_output_root_mean_squared_error: 1.9224 - y2_output_root_mean_squared_error: 2.6481 - val_loss: 18.3346 - val_y1_output_loss: 5.8032 - val_y2_output_loss: 12.3081 - val_y1_output_root_mean_squared_error: 2.4091 - val_y2_output_root_mean_squared_error: 3.5399
# Epoch 31/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.9248 - y1_output_loss: 3.4432 - y2_output_loss: 6.3893 - y1_output_root_mean_squared_error: 1.8642 - y2_output_root_mean_squared_error: 2.5396 - val_loss: 11.4325 - val_y1_output_loss: 4.5048 - val_y2_output_loss: 7.0711 - val_y1_output_root_mean_squared_error: 2.0778 - val_y2_output_root_mean_squared_error: 2.6675
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.4066 - y1_output_loss: 3.2229 - y2_output_loss: 5.1043 - y1_output_root_mean_squared_error: 1.8038 - y2_output_root_mean_squared_error: 2.2700 - val_loss: 9.8192 - val_y1_output_loss: 3.9380 - val_y2_output_loss: 6.0784 - val_y1_output_root_mean_squared_error: 1.9233 - val_y2_output_root_mean_squared_error: 2.4739
# Epoch 33/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.8978 - y1_output_loss: 3.6016 - y2_output_loss: 7.3619 - y1_output_root_mean_squared_error: 1.8849 - y2_output_root_mean_squared_error: 2.7102 - val_loss: 12.5441 - val_y1_output_loss: 3.8099 - val_y2_output_loss: 8.7630 - val_y1_output_root_mean_squared_error: 1.9159 - val_y2_output_root_mean_squared_error: 2.9788
# Epoch 34/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.9709 - y1_output_loss: 3.0560 - y2_output_loss: 5.9499 - y1_output_root_mean_squared_error: 1.7560 - y2_output_root_mean_squared_error: 2.4264 - val_loss: 10.5819 - val_y1_output_loss: 3.1357 - val_y2_output_loss: 7.3992 - val_y1_output_root_mean_squared_error: 1.7340 - val_y2_output_root_mean_squared_error: 2.7523
# Epoch 35/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.2622 - y1_output_loss: 2.4795 - y2_output_loss: 4.8234 - y1_output_root_mean_squared_error: 1.5792 - y2_output_root_mean_squared_error: 2.1836 - val_loss: 10.4868 - val_y1_output_loss: 3.4793 - val_y2_output_loss: 7.4327 - val_y1_output_root_mean_squared_error: 1.7813 - val_y2_output_root_mean_squared_error: 2.7044
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.6149 - y1_output_loss: 3.4509 - y2_output_loss: 7.1608 - y1_output_root_mean_squared_error: 1.8619 - y2_output_root_mean_squared_error: 2.6736 - val_loss: 11.2584 - val_y1_output_loss: 3.9012 - val_y2_output_loss: 7.7847 - val_y1_output_root_mean_squared_error: 1.8817 - val_y2_output_root_mean_squared_error: 2.7780
# Epoch 37/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1613 - y1_output_loss: 2.5497 - y2_output_loss: 4.5700 - y1_output_root_mean_squared_error: 1.6010 - y2_output_root_mean_squared_error: 2.1443 - val_loss: 10.5224 - val_y1_output_loss: 3.9441 - val_y2_output_loss: 6.5641 - val_y1_output_root_mean_squared_error: 1.9472 - val_y2_output_root_mean_squared_error: 2.5943
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.7440 - y1_output_loss: 2.4081 - y2_output_loss: 4.3316 - y1_output_root_mean_squared_error: 1.5407 - y2_output_root_mean_squared_error: 2.0905 - val_loss: 10.8077 - val_y1_output_loss: 3.6662 - val_y2_output_loss: 7.0488 - val_y1_output_root_mean_squared_error: 1.8981 - val_y2_output_root_mean_squared_error: 2.6842
# Epoch 39/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.5741 - y1_output_loss: 2.5555 - y2_output_loss: 5.0149 - y1_output_root_mean_squared_error: 1.6057 - y2_output_root_mean_squared_error: 2.2351 - val_loss: 16.0828 - val_y1_output_loss: 4.2780 - val_y2_output_loss: 12.4309 - val_y1_output_root_mean_squared_error: 1.9683 - val_y2_output_root_mean_squared_error: 3.4941
# Epoch 40/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.8876 - y1_output_loss: 2.4902 - y2_output_loss: 5.4919 - y1_output_root_mean_squared_error: 1.5676 - y2_output_root_mean_squared_error: 2.3303 - val_loss: 10.9227 - val_y1_output_loss: 4.9848 - val_y2_output_loss: 6.4498 - val_y1_output_root_mean_squared_error: 2.1302 - val_y2_output_root_mean_squared_error: 2.5268
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.1041 - y1_output_loss: 2.6181 - y2_output_loss: 5.5216 - y1_output_root_mean_squared_error: 1.6197 - y2_output_root_mean_squared_error: 2.3411 - val_loss: 15.1082 - val_y1_output_loss: 4.4158 - val_y2_output_loss: 11.0658 - val_y1_output_root_mean_squared_error: 2.0241 - val_y2_output_root_mean_squared_error: 3.3183
# Epoch 42/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.8296 - y1_output_loss: 2.7424 - y2_output_loss: 6.0767 - y1_output_root_mean_squared_error: 1.6535 - y2_output_root_mean_squared_error: 2.4689 - val_loss: 15.5348 - val_y1_output_loss: 5.0727 - val_y2_output_loss: 10.2171 - val_y1_output_root_mean_squared_error: 2.2670 - val_y2_output_root_mean_squared_error: 3.2242
# Epoch 43/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.8718 - y1_output_loss: 2.3323 - y2_output_loss: 4.5806 - y1_output_root_mean_squared_error: 1.5205 - y2_output_root_mean_squared_error: 2.1354 - val_loss: 9.3948 - val_y1_output_loss: 3.0919 - val_y2_output_loss: 6.5483 - val_y1_output_root_mean_squared_error: 1.6836 - val_y2_output_root_mean_squared_error: 2.5613
# Epoch 44/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.6359 - y1_output_loss: 2.4290 - y2_output_loss: 5.1513 - y1_output_root_mean_squared_error: 1.5645 - y2_output_root_mean_squared_error: 2.2778 - val_loss: 7.3689 - val_y1_output_loss: 2.3921 - val_y2_output_loss: 5.0377 - val_y1_output_root_mean_squared_error: 1.4836 - val_y2_output_root_mean_squared_error: 2.2733
# Epoch 45/500
# 614/614 [==============================] - 0s 164us/sample - loss: 6.7812 - y1_output_loss: 1.8138 - y2_output_loss: 5.0058 - y1_output_root_mean_squared_error: 1.3472 - y2_output_root_mean_squared_error: 2.2285 - val_loss: 14.0265 - val_y1_output_loss: 3.9203 - val_y2_output_loss: 10.1068 - val_y1_output_root_mean_squared_error: 1.9361 - val_y2_output_root_mean_squared_error: 3.2059
# Epoch 46/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.4646 - y1_output_loss: 2.0888 - y2_output_loss: 4.3897 - y1_output_root_mean_squared_error: 1.4490 - y2_output_root_mean_squared_error: 2.0892 - val_loss: 10.4136 - val_y1_output_loss: 3.0553 - val_y2_output_loss: 7.4928 - val_y1_output_root_mean_squared_error: 1.6908 - val_y2_output_root_mean_squared_error: 2.7486
# Epoch 47/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.1790 - y1_output_loss: 2.1213 - y2_output_loss: 5.0739 - y1_output_root_mean_squared_error: 1.4559 - y2_output_root_mean_squared_error: 2.2493 - val_loss: 8.0666 - val_y1_output_loss: 2.6079 - val_y2_output_loss: 5.7158 - val_y1_output_root_mean_squared_error: 1.5356 - val_y2_output_root_mean_squared_error: 2.3893
# Epoch 48/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.8841 - y1_output_loss: 2.4604 - y2_output_loss: 5.3582 - y1_output_root_mean_squared_error: 1.5760 - y2_output_root_mean_squared_error: 2.3238 - val_loss: 7.7996 - val_y1_output_loss: 2.5123 - val_y2_output_loss: 5.5041 - val_y1_output_root_mean_squared_error: 1.5130 - val_y2_output_root_mean_squared_error: 2.3474
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.1928 - y1_output_loss: 1.9728 - y2_output_loss: 4.2666 - y1_output_root_mean_squared_error: 1.3983 - y2_output_root_mean_squared_error: 2.0585 - val_loss: 21.4349 - val_y1_output_loss: 4.5501 - val_y2_output_loss: 16.3974 - val_y1_output_root_mean_squared_error: 2.1511 - val_y2_output_root_mean_squared_error: 4.0997
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.5192 - y1_output_loss: 1.9840 - y2_output_loss: 4.4741 - y1_output_root_mean_squared_error: 1.4153 - y2_output_root_mean_squared_error: 2.1251 - val_loss: 6.7545 - val_y1_output_loss: 2.2912 - val_y2_output_loss: 4.4545 - val_y1_output_root_mean_squared_error: 1.4872 - val_y2_output_root_mean_squared_error: 2.1314
# Epoch 51/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.9871 - y1_output_loss: 1.9757 - y2_output_loss: 4.0238 - y1_output_root_mean_squared_error: 1.3956 - y2_output_root_mean_squared_error: 2.0099 - val_loss: 9.6542 - val_y1_output_loss: 2.6236 - val_y2_output_loss: 6.9579 - val_y1_output_root_mean_squared_error: 1.6063 - val_y2_output_root_mean_squared_error: 2.6597
# Epoch 52/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.0306 - y1_output_loss: 2.0782 - y2_output_loss: 4.9436 - y1_output_root_mean_squared_error: 1.4376 - y2_output_root_mean_squared_error: 2.2280 - val_loss: 8.4532 - val_y1_output_loss: 2.1601 - val_y2_output_loss: 6.4230 - val_y1_output_root_mean_squared_error: 1.4199 - val_y2_output_root_mean_squared_error: 2.5371
# Epoch 53/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.6808 - y1_output_loss: 1.9862 - y2_output_loss: 4.6341 - y1_output_root_mean_squared_error: 1.4155 - y2_output_root_mean_squared_error: 2.1627 - val_loss: 9.4523 - val_y1_output_loss: 2.4113 - val_y2_output_loss: 6.9615 - val_y1_output_root_mean_squared_error: 1.5349 - val_y2_output_root_mean_squared_error: 2.6639
# Epoch 54/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.1260 - y1_output_loss: 2.0438 - y2_output_loss: 5.4633 - y1_output_root_mean_squared_error: 1.3979 - y2_output_root_mean_squared_error: 2.2742 - val_loss: 111.8739 - val_y1_output_loss: 27.2094 - val_y2_output_loss: 85.8859 - val_y1_output_root_mean_squared_error: 5.1725 - val_y2_output_root_mean_squared_error: 9.2260
# Epoch 55/500
# 614/614 [==============================] - 0s 163us/sample - loss: 13.3833 - y1_output_loss: 4.1543 - y2_output_loss: 9.1380 - y1_output_root_mean_squared_error: 2.0439 - y2_output_root_mean_squared_error: 3.0341 - val_loss: 6.7343 - val_y1_output_loss: 2.3154 - val_y2_output_loss: 4.5788 - val_y1_output_root_mean_squared_error: 1.4515 - val_y2_output_root_mean_squared_error: 2.1511
# Epoch 56/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.5472 - y1_output_loss: 1.7002 - y2_output_loss: 3.8153 - y1_output_root_mean_squared_error: 1.3092 - y2_output_root_mean_squared_error: 1.9579 - val_loss: 6.9118 - val_y1_output_loss: 1.9237 - val_y2_output_loss: 5.0307 - val_y1_output_root_mean_squared_error: 1.3503 - val_y2_output_root_mean_squared_error: 2.2558
# Epoch 57/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1372 - y1_output_loss: 1.8119 - y2_output_loss: 4.3874 - y1_output_root_mean_squared_error: 1.3347 - y2_output_root_mean_squared_error: 2.0870 - val_loss: 15.0402 - val_y1_output_loss: 4.7711 - val_y2_output_loss: 9.8547 - val_y1_output_root_mean_squared_error: 2.2082 - val_y2_output_root_mean_squared_error: 3.1881
# Epoch 58/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1307 - y1_output_loss: 1.8454 - y2_output_loss: 4.2744 - y1_output_root_mean_squared_error: 1.3577 - y2_output_root_mean_squared_error: 2.0706 - val_loss: 7.0707 - val_y1_output_loss: 2.2551 - val_y2_output_loss: 4.8061 - val_y1_output_root_mean_squared_error: 1.4651 - val_y2_output_root_mean_squared_error: 2.2191
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.0103 - y1_output_loss: 1.5715 - y2_output_loss: 3.4851 - y1_output_root_mean_squared_error: 1.2343 - y2_output_root_mean_squared_error: 1.8673 - val_loss: 15.2706 - val_y1_output_loss: 5.2158 - val_y2_output_loss: 9.6314 - val_y1_output_root_mean_squared_error: 2.3101 - val_y2_output_root_mean_squared_error: 3.1518
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.1289 - y1_output_loss: 1.9341 - y2_output_loss: 4.2427 - y1_output_root_mean_squared_error: 1.3871 - y2_output_root_mean_squared_error: 2.0505 - val_loss: 12.7127 - val_y1_output_loss: 4.4483 - val_y2_output_loss: 8.7657 - val_y1_output_root_mean_squared_error: 2.0132 - val_y2_output_root_mean_squared_error: 2.9427
# Epoch 61/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.2587 - y1_output_loss: 1.6381 - y2_output_loss: 4.5862 - y1_output_root_mean_squared_error: 1.2842 - y2_output_root_mean_squared_error: 2.1470 - val_loss: 5.9920 - val_y1_output_loss: 1.7607 - val_y2_output_loss: 4.3723 - val_y1_output_root_mean_squared_error: 1.2554 - val_y2_output_root_mean_squared_error: 2.1014
# Epoch 62/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.3982 - y1_output_loss: 1.3728 - y2_output_loss: 4.0637 - y1_output_root_mean_squared_error: 1.1718 - y2_output_root_mean_squared_error: 2.0062 - val_loss: 4.9331 - val_y1_output_loss: 1.3981 - val_y2_output_loss: 3.6001 - val_y1_output_root_mean_squared_error: 1.1245 - val_y2_output_root_mean_squared_error: 1.9153
# Epoch 63/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.0316 - y1_output_loss: 1.4282 - y2_output_loss: 3.5770 - y1_output_root_mean_squared_error: 1.1945 - y2_output_root_mean_squared_error: 1.8986 - val_loss: 6.5627 - val_y1_output_loss: 1.7644 - val_y2_output_loss: 4.8280 - val_y1_output_root_mean_squared_error: 1.2958 - val_y2_output_root_mean_squared_error: 2.2099
# Epoch 64/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.3553 - y1_output_loss: 1.2496 - y2_output_loss: 3.0930 - y1_output_root_mean_squared_error: 1.1216 - y2_output_root_mean_squared_error: 1.7599 - val_loss: 5.1149 - val_y1_output_loss: 1.4230 - val_y2_output_loss: 3.7393 - val_y1_output_root_mean_squared_error: 1.1283 - val_y2_output_root_mean_squared_error: 1.9601
# Epoch 65/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2130 - y1_output_loss: 1.6019 - y2_output_loss: 4.6261 - y1_output_root_mean_squared_error: 1.2617 - y2_output_root_mean_squared_error: 2.1497 - val_loss: 5.7582 - val_y1_output_loss: 1.4576 - val_y2_output_loss: 4.3766 - val_y1_output_root_mean_squared_error: 1.1447 - val_y2_output_root_mean_squared_error: 2.1090
# Epoch 66/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.5738 - y1_output_loss: 1.2473 - y2_output_loss: 3.3201 - y1_output_root_mean_squared_error: 1.1152 - y2_output_root_mean_squared_error: 1.8249 - val_loss: 5.0621 - val_y1_output_loss: 1.3336 - val_y2_output_loss: 3.7593 - val_y1_output_root_mean_squared_error: 1.1201 - val_y2_output_root_mean_squared_error: 1.9513
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1996 - y1_output_loss: 1.5334 - y2_output_loss: 3.6390 - y1_output_root_mean_squared_error: 1.2415 - y2_output_root_mean_squared_error: 1.9126 - val_loss: 5.5920 - val_y1_output_loss: 1.4358 - val_y2_output_loss: 4.1309 - val_y1_output_root_mean_squared_error: 1.1635 - val_y2_output_root_mean_squared_error: 2.0587
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.3537 - y1_output_loss: 1.0467 - y2_output_loss: 3.3064 - y1_output_root_mean_squared_error: 1.0173 - y2_output_root_mean_squared_error: 1.8218 - val_loss: 6.8630 - val_y1_output_loss: 2.3714 - val_y2_output_loss: 4.3318 - val_y1_output_root_mean_squared_error: 1.5464 - val_y2_output_root_mean_squared_error: 2.1146
# Epoch 69/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.8322 - y1_output_loss: 1.3529 - y2_output_loss: 3.4470 - y1_output_root_mean_squared_error: 1.1645 - y2_output_root_mean_squared_error: 1.8645 - val_loss: 4.0884 - val_y1_output_loss: 1.2397 - val_y2_output_loss: 2.8855 - val_y1_output_root_mean_squared_error: 1.0580 - val_y2_output_root_mean_squared_error: 1.7231
# Epoch 70/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.3412 - y1_output_loss: 1.2031 - y2_output_loss: 3.1289 - y1_output_root_mean_squared_error: 1.0964 - y2_output_root_mean_squared_error: 1.7717 - val_loss: 4.8302 - val_y1_output_loss: 1.3837 - val_y2_output_loss: 3.5802 - val_y1_output_root_mean_squared_error: 1.1324 - val_y2_output_root_mean_squared_error: 1.8836
# Epoch 71/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.0105 - y1_output_loss: 0.9636 - y2_output_loss: 3.0188 - y1_output_root_mean_squared_error: 0.9824 - y2_output_root_mean_squared_error: 1.7451 - val_loss: 5.5212 - val_y1_output_loss: 1.0714 - val_y2_output_loss: 4.3662 - val_y1_output_root_mean_squared_error: 1.0232 - val_y2_output_root_mean_squared_error: 2.1153
# Epoch 72/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.1687 - y1_output_loss: 0.7771 - y2_output_loss: 2.3762 - y1_output_root_mean_squared_error: 0.8821 - y2_output_root_mean_squared_error: 1.5461 - val_loss: 8.1908 - val_y1_output_loss: 1.2668 - val_y2_output_loss: 6.9774 - val_y1_output_root_mean_squared_error: 1.0714 - val_y2_output_root_mean_squared_error: 2.6538
# Epoch 73/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.9280 - y1_output_loss: 0.9100 - y2_output_loss: 3.0374 - y1_output_root_mean_squared_error: 0.9515 - y2_output_root_mean_squared_error: 1.7386 - val_loss: 9.3146 - val_y1_output_loss: 1.8766 - val_y2_output_loss: 7.5042 - val_y1_output_root_mean_squared_error: 1.3298 - val_y2_output_root_mean_squared_error: 2.7470
# Epoch 74/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.0422 - y1_output_loss: 0.9698 - y2_output_loss: 3.0625 - y1_output_root_mean_squared_error: 0.9886 - y2_output_root_mean_squared_error: 1.7507 - val_loss: 3.6843 - val_y1_output_loss: 0.9270 - val_y2_output_loss: 2.8186 - val_y1_output_root_mean_squared_error: 0.9039 - val_y2_output_root_mean_squared_error: 1.6933
# Epoch 75/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4023 - y1_output_loss: 0.8422 - y2_output_loss: 2.5526 - y1_output_root_mean_squared_error: 0.9148 - y2_output_root_mean_squared_error: 1.6017 - val_loss: 4.9201 - val_y1_output_loss: 1.1223 - val_y2_output_loss: 3.7079 - val_y1_output_root_mean_squared_error: 1.0395 - val_y2_output_root_mean_squared_error: 1.9594
# Epoch 76/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.0577 - y1_output_loss: 1.3304 - y2_output_loss: 3.7649 - y1_output_root_mean_squared_error: 1.1546 - y2_output_root_mean_squared_error: 1.9300 - val_loss: 7.8201 - val_y1_output_loss: 1.7947 - val_y2_output_loss: 6.0562 - val_y1_output_root_mean_squared_error: 1.2971 - val_y2_output_root_mean_squared_error: 2.4774
# Epoch 77/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.5318 - y1_output_loss: 1.0592 - y2_output_loss: 3.4334 - y1_output_root_mean_squared_error: 1.0338 - y2_output_root_mean_squared_error: 1.8609 - val_loss: 3.8101 - val_y1_output_loss: 0.8244 - val_y2_output_loss: 2.9765 - val_y1_output_root_mean_squared_error: 0.8697 - val_y2_output_root_mean_squared_error: 1.7475
# Epoch 78/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8704 - y1_output_loss: 0.7056 - y2_output_loss: 2.1460 - y1_output_root_mean_squared_error: 0.8430 - y2_output_root_mean_squared_error: 1.4696 - val_loss: 3.2303 - val_y1_output_loss: 0.6868 - val_y2_output_loss: 2.5376 - val_y1_output_root_mean_squared_error: 0.7926 - val_y2_output_root_mean_squared_error: 1.6131
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.3227 - y1_output_loss: 1.7756 - y2_output_loss: 5.5237 - y1_output_root_mean_squared_error: 1.3378 - y2_output_root_mean_squared_error: 2.3522 - val_loss: 6.4759 - val_y1_output_loss: 0.8271 - val_y2_output_loss: 5.5828 - val_y1_output_root_mean_squared_error: 0.8917 - val_y2_output_root_mean_squared_error: 2.3835
# Epoch 80/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.4827 - y1_output_loss: 0.7999 - y2_output_loss: 2.6807 - y1_output_root_mean_squared_error: 0.8958 - y2_output_root_mean_squared_error: 1.6371 - val_loss: 5.9250 - val_y1_output_loss: 1.7507 - val_y2_output_loss: 4.2658 - val_y1_output_root_mean_squared_error: 1.2976 - val_y2_output_root_mean_squared_error: 2.0594
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2306 - y1_output_loss: 0.9765 - y2_output_loss: 2.2392 - y1_output_root_mean_squared_error: 0.9905 - y2_output_root_mean_squared_error: 1.4998 - val_loss: 4.5456 - val_y1_output_loss: 0.6782 - val_y2_output_loss: 3.8433 - val_y1_output_root_mean_squared_error: 0.7745 - val_y2_output_root_mean_squared_error: 1.9864
# Epoch 82/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.9289 - y1_output_loss: 0.8955 - y2_output_loss: 3.0650 - y1_output_root_mean_squared_error: 0.9459 - y2_output_root_mean_squared_error: 1.7419 - val_loss: 3.3045 - val_y1_output_loss: 0.8301 - val_y2_output_loss: 2.5310 - val_y1_output_root_mean_squared_error: 0.8491 - val_y2_output_root_mean_squared_error: 1.6073
# Epoch 83/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2066 - y1_output_loss: 0.7816 - y2_output_loss: 2.4226 - y1_output_root_mean_squared_error: 0.8824 - y2_output_root_mean_squared_error: 1.5582 - val_loss: 3.8416 - val_y1_output_loss: 1.1128 - val_y2_output_loss: 2.8583 - val_y1_output_root_mean_squared_error: 0.9739 - val_y2_output_root_mean_squared_error: 1.7009
# Epoch 84/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.8141 - y1_output_loss: 0.8098 - y2_output_loss: 2.9688 - y1_output_root_mean_squared_error: 0.9039 - y2_output_root_mean_squared_error: 1.7312 - val_loss: 3.6615 - val_y1_output_loss: 0.8803 - val_y2_output_loss: 2.7691 - val_y1_output_root_mean_squared_error: 0.9240 - val_y2_output_root_mean_squared_error: 1.6756
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9497 - y1_output_loss: 0.6244 - y2_output_loss: 2.3028 - y1_output_root_mean_squared_error: 0.7926 - y2_output_root_mean_squared_error: 1.5236 - val_loss: 3.5413 - val_y1_output_loss: 0.8774 - val_y2_output_loss: 2.6699 - val_y1_output_root_mean_squared_error: 0.9196 - val_y2_output_root_mean_squared_error: 1.6418
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7826 - y1_output_loss: 1.4561 - y2_output_loss: 4.3194 - y1_output_root_mean_squared_error: 1.2101 - y2_output_root_mean_squared_error: 2.0780 - val_loss: 4.3988 - val_y1_output_loss: 1.1032 - val_y2_output_loss: 3.3808 - val_y1_output_root_mean_squared_error: 0.9894 - val_y2_output_root_mean_squared_error: 1.8493
# Epoch 87/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.5451 - y1_output_loss: 0.7835 - y2_output_loss: 2.7497 - y1_output_root_mean_squared_error: 0.8894 - y2_output_root_mean_squared_error: 1.6596 - val_loss: 3.0195 - val_y1_output_loss: 0.6416 - val_y2_output_loss: 2.3784 - val_y1_output_root_mean_squared_error: 0.7667 - val_y2_output_root_mean_squared_error: 1.5594
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5908 - y1_output_loss: 0.7382 - y2_output_loss: 2.8196 - y1_output_root_mean_squared_error: 0.8629 - y2_output_root_mean_squared_error: 1.6871 - val_loss: 3.2633 - val_y1_output_loss: 0.6645 - val_y2_output_loss: 2.6269 - val_y1_output_root_mean_squared_error: 0.7850 - val_y2_output_root_mean_squared_error: 1.6270
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2041 - y1_output_loss: 0.7763 - y2_output_loss: 2.4153 - y1_output_root_mean_squared_error: 0.8842 - y2_output_root_mean_squared_error: 1.5564 - val_loss: 4.2010 - val_y1_output_loss: 0.9670 - val_y2_output_loss: 3.3926 - val_y1_output_root_mean_squared_error: 0.9074 - val_y2_output_root_mean_squared_error: 1.8378
# Epoch 90/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.7921 - y1_output_loss: 0.8211 - y2_output_loss: 2.9466 - y1_output_root_mean_squared_error: 0.9066 - y2_output_root_mean_squared_error: 1.7234 - val_loss: 3.1269 - val_y1_output_loss: 0.6994 - val_y2_output_loss: 2.4599 - val_y1_output_root_mean_squared_error: 0.8013 - val_y2_output_root_mean_squared_error: 1.5763
# Epoch 91/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.5979 - y1_output_loss: 0.7752 - y2_output_loss: 2.8241 - y1_output_root_mean_squared_error: 0.8762 - y2_output_root_mean_squared_error: 1.6823 - val_loss: 4.8225 - val_y1_output_loss: 1.4962 - val_y2_output_loss: 3.3386 - val_y1_output_root_mean_squared_error: 1.1820 - val_y2_output_root_mean_squared_error: 1.8508
# Epoch 92/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.0178 - y1_output_loss: 0.6803 - y2_output_loss: 2.3129 - y1_output_root_mean_squared_error: 0.8268 - y2_output_root_mean_squared_error: 1.5278 - val_loss: 3.1798 - val_y1_output_loss: 0.6817 - val_y2_output_loss: 2.4922 - val_y1_output_root_mean_squared_error: 0.7982 - val_y2_output_root_mean_squared_error: 1.5946
# Epoch 93/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0657 - y1_output_loss: 0.7600 - y2_output_loss: 2.2841 - y1_output_root_mean_squared_error: 0.8731 - y2_output_root_mean_squared_error: 1.5177 - val_loss: 2.7354 - val_y1_output_loss: 0.5549 - val_y2_output_loss: 2.1755 - val_y1_output_root_mean_squared_error: 0.7156 - val_y2_output_root_mean_squared_error: 1.4911
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.0379 - y1_output_loss: 1.3855 - y2_output_loss: 3.8461 - y1_output_root_mean_squared_error: 1.1523 - y2_output_root_mean_squared_error: 1.9261 - val_loss: 37.7023 - val_y1_output_loss: 12.7638 - val_y2_output_loss: 27.3738 - val_y1_output_root_mean_squared_error: 3.4382 - val_y2_output_root_mean_squared_error: 5.0873
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.7054 - y1_output_loss: 1.1354 - y2_output_loss: 3.5300 - y1_output_root_mean_squared_error: 1.0696 - y2_output_root_mean_squared_error: 1.8872 - val_loss: 3.4260 - val_y1_output_loss: 0.6975 - val_y2_output_loss: 2.7257 - val_y1_output_root_mean_squared_error: 0.8222 - val_y2_output_root_mean_squared_error: 1.6583
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8619 - y1_output_loss: 0.6131 - y2_output_loss: 2.2487 - y1_output_root_mean_squared_error: 0.7817 - y2_output_root_mean_squared_error: 1.5003 - val_loss: 2.8875 - val_y1_output_loss: 0.6871 - val_y2_output_loss: 2.2046 - val_y1_output_root_mean_squared_error: 0.8115 - val_y2_output_root_mean_squared_error: 1.4930
# Epoch 97/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0308 - y1_output_loss: 1.0361 - y2_output_loss: 2.9701 - y1_output_root_mean_squared_error: 1.0197 - y2_output_root_mean_squared_error: 1.7295 - val_loss: 4.0347 - val_y1_output_loss: 0.8958 - val_y2_output_loss: 3.1145 - val_y1_output_root_mean_squared_error: 0.9405 - val_y2_output_root_mean_squared_error: 1.7749
# Epoch 98/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.5776 - y1_output_loss: 0.5260 - y2_output_loss: 2.0298 - y1_output_root_mean_squared_error: 0.7283 - y2_output_root_mean_squared_error: 1.4308 - val_loss: 2.8304 - val_y1_output_loss: 0.5714 - val_y2_output_loss: 2.2286 - val_y1_output_root_mean_squared_error: 0.7329 - val_y2_output_root_mean_squared_error: 1.5144
# Epoch 99/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.8224 - y1_output_loss: 1.1821 - y2_output_loss: 3.6089 - y1_output_root_mean_squared_error: 1.0882 - y2_output_root_mean_squared_error: 1.9074 - val_loss: 4.2654 - val_y1_output_loss: 1.1358 - val_y2_output_loss: 3.0276 - val_y1_output_root_mean_squared_error: 1.0731 - val_y2_output_root_mean_squared_error: 1.7646
# Epoch 100/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5566 - y1_output_loss: 0.8307 - y2_output_loss: 2.7138 - y1_output_root_mean_squared_error: 0.9089 - y2_output_root_mean_squared_error: 1.6524 - val_loss: 3.0824 - val_y1_output_loss: 0.7962 - val_y2_output_loss: 2.3418 - val_y1_output_root_mean_squared_error: 0.8701 - val_y2_output_root_mean_squared_error: 1.5249
# Epoch 101/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3439 - y1_output_loss: 0.7303 - y2_output_loss: 2.5904 - y1_output_root_mean_squared_error: 0.8579 - y2_output_root_mean_squared_error: 1.6149 - val_loss: 3.5290 - val_y1_output_loss: 0.5746 - val_y2_output_loss: 2.9719 - val_y1_output_root_mean_squared_error: 0.7418 - val_y2_output_root_mean_squared_error: 1.7259
# Epoch 102/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7192 - y1_output_loss: 0.6172 - y2_output_loss: 2.1177 - y1_output_root_mean_squared_error: 0.7885 - y2_output_root_mean_squared_error: 1.4483 - val_loss: 4.5215 - val_y1_output_loss: 0.5743 - val_y2_output_loss: 3.9953 - val_y1_output_root_mean_squared_error: 0.7367 - val_y2_output_root_mean_squared_error: 1.9947
# Epoch 103/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.7798 - y1_output_loss: 0.6202 - y2_output_loss: 2.1840 - y1_output_root_mean_squared_error: 0.7875 - y2_output_root_mean_squared_error: 1.4696 - val_loss: 6.1508 - val_y1_output_loss: 1.1500 - val_y2_output_loss: 4.9352 - val_y1_output_root_mean_squared_error: 1.0686 - val_y2_output_root_mean_squared_error: 2.2380
# Epoch 104/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2688 - y1_output_loss: 0.5377 - y2_output_loss: 1.7481 - y1_output_root_mean_squared_error: 0.7336 - y2_output_root_mean_squared_error: 1.3155 - val_loss: 9.4474 - val_y1_output_loss: 1.6696 - val_y2_output_loss: 7.9481 - val_y1_output_root_mean_squared_error: 1.2381 - val_y2_output_root_mean_squared_error: 2.8133
# Epoch 105/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8067 - y1_output_loss: 0.6846 - y2_output_loss: 2.1411 - y1_output_root_mean_squared_error: 0.8305 - y2_output_root_mean_squared_error: 1.4550 - val_loss: 10.9250 - val_y1_output_loss: 1.4710 - val_y2_output_loss: 9.3789 - val_y1_output_root_mean_squared_error: 1.1873 - val_y2_output_root_mean_squared_error: 3.0847
# Epoch 106/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4680 - y1_output_loss: 0.5647 - y2_output_loss: 1.8884 - y1_output_root_mean_squared_error: 0.7532 - y2_output_root_mean_squared_error: 1.3786 - val_loss: 3.0238 - val_y1_output_loss: 0.7573 - val_y2_output_loss: 2.2947 - val_y1_output_root_mean_squared_error: 0.8577 - val_y2_output_root_mean_squared_error: 1.5127
# Epoch 107/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1240 - y1_output_loss: 0.6534 - y2_output_loss: 2.5917 - y1_output_root_mean_squared_error: 0.7995 - y2_output_root_mean_squared_error: 1.5763 - val_loss: 5.0481 - val_y1_output_loss: 1.1531 - val_y2_output_loss: 3.9272 - val_y1_output_root_mean_squared_error: 1.0396 - val_y2_output_root_mean_squared_error: 1.9918
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4372 - y1_output_loss: 0.4985 - y2_output_loss: 1.9279 - y1_output_root_mean_squared_error: 0.7087 - y2_output_root_mean_squared_error: 1.3910 - val_loss: 3.0068 - val_y1_output_loss: 0.4970 - val_y2_output_loss: 2.5249 - val_y1_output_root_mean_squared_error: 0.6732 - val_y2_output_root_mean_squared_error: 1.5980
# Epoch 109/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4916 - y1_output_loss: 0.6636 - y2_output_loss: 1.8469 - y1_output_root_mean_squared_error: 0.8116 - y2_output_root_mean_squared_error: 1.3538 - val_loss: 10.0719 - val_y1_output_loss: 3.2708 - val_y2_output_loss: 7.0254 - val_y1_output_root_mean_squared_error: 1.7885 - val_y2_output_root_mean_squared_error: 2.6217
# Epoch 110/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2394 - y1_output_loss: 1.0385 - y2_output_loss: 3.1739 - y1_output_root_mean_squared_error: 1.0233 - y2_output_root_mean_squared_error: 1.7867 - val_loss: 2.6071 - val_y1_output_loss: 0.6501 - val_y2_output_loss: 1.9914 - val_y1_output_root_mean_squared_error: 0.7729 - val_y2_output_root_mean_squared_error: 1.4176
# Epoch 111/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2279 - y1_output_loss: 0.4369 - y2_output_loss: 1.8176 - y1_output_root_mean_squared_error: 0.6639 - y2_output_root_mean_squared_error: 1.3368 - val_loss: 9.2598 - val_y1_output_loss: 1.2201 - val_y2_output_loss: 8.0439 - val_y1_output_root_mean_squared_error: 1.0712 - val_y2_output_root_mean_squared_error: 2.8482
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5662 - y1_output_loss: 0.6060 - y2_output_loss: 1.9447 - y1_output_root_mean_squared_error: 0.7813 - y2_output_root_mean_squared_error: 1.3985 - val_loss: 2.9062 - val_y1_output_loss: 0.7428 - val_y2_output_loss: 2.1868 - val_y1_output_root_mean_squared_error: 0.8240 - val_y2_output_root_mean_squared_error: 1.4924
# Epoch 113/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5132 - y1_output_loss: 0.5522 - y2_output_loss: 1.9468 - y1_output_root_mean_squared_error: 0.7459 - y2_output_root_mean_squared_error: 1.3989 - val_loss: 2.6675 - val_y1_output_loss: 0.6231 - val_y2_output_loss: 2.0031 - val_y1_output_root_mean_squared_error: 0.7844 - val_y2_output_root_mean_squared_error: 1.4325
# Epoch 114/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3996 - y1_output_loss: 0.7427 - y2_output_loss: 2.6603 - y1_output_root_mean_squared_error: 0.8612 - y2_output_root_mean_squared_error: 1.6303 - val_loss: 3.2194 - val_y1_output_loss: 0.4771 - val_y2_output_loss: 2.7188 - val_y1_output_root_mean_squared_error: 0.6673 - val_y2_output_root_mean_squared_error: 1.6656
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3439 - y1_output_loss: 0.5197 - y2_output_loss: 1.8047 - y1_output_root_mean_squared_error: 0.7235 - y2_output_root_mean_squared_error: 1.3492 - val_loss: 2.4098 - val_y1_output_loss: 0.5097 - val_y2_output_loss: 1.8944 - val_y1_output_root_mean_squared_error: 0.7036 - val_y2_output_root_mean_squared_error: 1.3837
# Epoch 116/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3241 - y1_output_loss: 0.5590 - y2_output_loss: 1.7615 - y1_output_root_mean_squared_error: 0.7474 - y2_output_root_mean_squared_error: 1.3287 - val_loss: 4.1610 - val_y1_output_loss: 1.4682 - val_y2_output_loss: 2.8159 - val_y1_output_root_mean_squared_error: 1.1543 - val_y2_output_root_mean_squared_error: 1.6818
# Epoch 117/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0980 - y1_output_loss: 0.6977 - y2_output_loss: 2.3947 - y1_output_root_mean_squared_error: 0.8371 - y2_output_root_mean_squared_error: 1.5483 - val_loss: 4.6827 - val_y1_output_loss: 1.3811 - val_y2_output_loss: 3.3329 - val_y1_output_root_mean_squared_error: 1.1537 - val_y2_output_root_mean_squared_error: 1.8307
# Epoch 118/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7702 - y1_output_loss: 0.6017 - y2_output_loss: 2.1500 - y1_output_root_mean_squared_error: 0.7793 - y2_output_root_mean_squared_error: 1.4707 - val_loss: 4.0474 - val_y1_output_loss: 0.7081 - val_y2_output_loss: 3.3572 - val_y1_output_root_mean_squared_error: 0.8084 - val_y2_output_root_mean_squared_error: 1.8423
# Epoch 119/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2639 - y1_output_loss: 0.4913 - y2_output_loss: 1.8013 - y1_output_root_mean_squared_error: 0.6999 - y2_output_root_mean_squared_error: 1.3319 - val_loss: 9.2591 - val_y1_output_loss: 1.6495 - val_y2_output_loss: 7.5642 - val_y1_output_root_mean_squared_error: 1.2680 - val_y2_output_root_mean_squared_error: 2.7661
# Epoch 120/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5175 - y1_output_loss: 0.5045 - y2_output_loss: 2.0037 - y1_output_root_mean_squared_error: 0.7127 - y2_output_root_mean_squared_error: 1.4176 - val_loss: 3.3820 - val_y1_output_loss: 0.8242 - val_y2_output_loss: 2.5672 - val_y1_output_root_mean_squared_error: 0.8785 - val_y2_output_root_mean_squared_error: 1.6156
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4629 - y1_output_loss: 0.1232 - y2_output_loss: 0.3399 - y1_output_root_mean_squared_error: 0.3520 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 1.3158 - val_y1_output_loss: 0.2544 - val_y2_output_loss: 1.1090 - val_y1_output_root_mean_squared_error: 0.4890 - val_y2_output_root_mean_squared_error: 1.0376
# Epoch 462/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.6341 - y1_output_loss: 0.1491 - y2_output_loss: 0.4858 - y1_output_root_mean_squared_error: 0.3856 - y2_output_root_mean_squared_error: 0.6967 - val_loss: 1.7558 - val_y1_output_loss: 0.5902 - val_y2_output_loss: 1.1715 - val_y1_output_root_mean_squared_error: 0.7766 - val_y2_output_root_mean_squared_error: 1.0736
# Epoch 463/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.8497 - y1_output_loss: 0.1862 - y2_output_loss: 0.6570 - y1_output_root_mean_squared_error: 0.4318 - y2_output_root_mean_squared_error: 0.8144 - val_loss: 1.0635 - val_y1_output_loss: 0.2896 - val_y2_output_loss: 0.8182 - val_y1_output_root_mean_squared_error: 0.5101 - val_y2_output_root_mean_squared_error: 0.8962
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4530 - y1_output_loss: 0.1198 - y2_output_loss: 0.3329 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.5772 - val_loss: 1.4037 - val_y1_output_loss: 0.2736 - val_y2_output_loss: 1.1322 - val_y1_output_root_mean_squared_error: 0.5165 - val_y2_output_root_mean_squared_error: 1.0663
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4183 - y1_output_loss: 0.1216 - y2_output_loss: 0.3047 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5443 - val_loss: 3.3627 - val_y1_output_loss: 0.4090 - val_y2_output_loss: 3.0627 - val_y1_output_root_mean_squared_error: 0.6151 - val_y2_output_root_mean_squared_error: 1.7276
# Epoch 466/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6013 - y1_output_loss: 0.1377 - y2_output_loss: 0.4594 - y1_output_root_mean_squared_error: 0.3721 - y2_output_root_mean_squared_error: 0.6803 - val_loss: 0.9017 - val_y1_output_loss: 0.2093 - val_y2_output_loss: 0.7060 - val_y1_output_root_mean_squared_error: 0.4541 - val_y2_output_root_mean_squared_error: 0.8340
# Epoch 467/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5696 - y1_output_loss: 0.1372 - y2_output_loss: 0.4293 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.6579 - val_loss: 0.9660 - val_y1_output_loss: 0.2337 - val_y2_output_loss: 0.7476 - val_y1_output_root_mean_squared_error: 0.4777 - val_y2_output_root_mean_squared_error: 0.8589
# Epoch 468/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4174 - y1_output_loss: 0.1248 - y2_output_loss: 0.2893 - y1_output_root_mean_squared_error: 0.3544 - y2_output_root_mean_squared_error: 0.5402 - val_loss: 0.9312 - val_y1_output_loss: 0.2227 - val_y2_output_loss: 0.7132 - val_y1_output_root_mean_squared_error: 0.4710 - val_y2_output_root_mean_squared_error: 0.8422
# Epoch 469/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4007 - y1_output_loss: 0.1025 - y2_output_loss: 0.2952 - y1_output_root_mean_squared_error: 0.3211 - y2_output_root_mean_squared_error: 0.5455 - val_loss: 0.9500 - val_y1_output_loss: 0.2288 - val_y2_output_loss: 0.7512 - val_y1_output_root_mean_squared_error: 0.4664 - val_y2_output_root_mean_squared_error: 0.8559
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5380 - y1_output_loss: 0.1431 - y2_output_loss: 0.3921 - y1_output_root_mean_squared_error: 0.3789 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 1.0116 - val_y1_output_loss: 0.2332 - val_y2_output_loss: 0.8199 - val_y1_output_root_mean_squared_error: 0.4628 - val_y2_output_root_mean_squared_error: 0.8930
# Epoch 471/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4393 - y1_output_loss: 0.1240 - y2_output_loss: 0.3121 - y1_output_root_mean_squared_error: 0.3532 - y2_output_root_mean_squared_error: 0.5608 - val_loss: 1.0967 - val_y1_output_loss: 0.2568 - val_y2_output_loss: 0.8335 - val_y1_output_root_mean_squared_error: 0.5044 - val_y2_output_root_mean_squared_error: 0.9177
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3586 - y1_output_loss: 0.1066 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3275 - y2_output_root_mean_squared_error: 0.5014 - val_loss: 1.3188 - val_y1_output_loss: 0.3317 - val_y2_output_loss: 0.9743 - val_y1_output_root_mean_squared_error: 0.5850 - val_y2_output_root_mean_squared_error: 0.9883
# Epoch 473/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4282 - y1_output_loss: 0.1360 - y2_output_loss: 0.2914 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5401 - val_loss: 0.9306 - val_y1_output_loss: 0.2355 - val_y2_output_loss: 0.7078 - val_y1_output_root_mean_squared_error: 0.4774 - val_y2_output_root_mean_squared_error: 0.8383
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4292 - y1_output_loss: 0.1169 - y2_output_loss: 0.3089 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5582 - val_loss: 0.8699 - val_y1_output_loss: 0.2204 - val_y2_output_loss: 0.6574 - val_y1_output_root_mean_squared_error: 0.4631 - val_y2_output_root_mean_squared_error: 0.8096
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5005 - y1_output_loss: 0.1455 - y2_output_loss: 0.3521 - y1_output_root_mean_squared_error: 0.3809 - y2_output_root_mean_squared_error: 0.5962 - val_loss: 0.9320 - val_y1_output_loss: 0.2869 - val_y2_output_loss: 0.6807 - val_y1_output_root_mean_squared_error: 0.5192 - val_y2_output_root_mean_squared_error: 0.8139
# Epoch 476/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3803 - y1_output_loss: 0.1095 - y2_output_loss: 0.2693 - y1_output_root_mean_squared_error: 0.3314 - y2_output_root_mean_squared_error: 0.5201 - val_loss: 0.8979 - val_y1_output_loss: 0.2225 - val_y2_output_loss: 0.7111 - val_y1_output_root_mean_squared_error: 0.4615 - val_y2_output_root_mean_squared_error: 0.8276
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4033 - y1_output_loss: 0.1266 - y2_output_loss: 0.2735 - y1_output_root_mean_squared_error: 0.3570 - y2_output_root_mean_squared_error: 0.5252 - val_loss: 0.9249 - val_y1_output_loss: 0.2285 - val_y2_output_loss: 0.7084 - val_y1_output_root_mean_squared_error: 0.4778 - val_y2_output_root_mean_squared_error: 0.8346
# Epoch 478/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4155 - y1_output_loss: 0.1139 - y2_output_loss: 0.2992 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.5488 - val_loss: 1.0626 - val_y1_output_loss: 0.2617 - val_y2_output_loss: 0.8024 - val_y1_output_root_mean_squared_error: 0.5063 - val_y2_output_root_mean_squared_error: 0.8979
# Epoch 479/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4709 - y1_output_loss: 0.1236 - y2_output_loss: 0.3463 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.5891 - val_loss: 1.4854 - val_y1_output_loss: 0.4008 - val_y2_output_loss: 1.1097 - val_y1_output_root_mean_squared_error: 0.6367 - val_y2_output_root_mean_squared_error: 1.0393
# Epoch 480/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.9663 - y1_output_loss: 0.2016 - y2_output_loss: 0.7569 - y1_output_root_mean_squared_error: 0.4508 - y2_output_root_mean_squared_error: 0.8736 - val_loss: 1.2354 - val_y1_output_loss: 0.3006 - val_y2_output_loss: 1.0188 - val_y1_output_root_mean_squared_error: 0.5177 - val_y2_output_root_mean_squared_error: 0.9835
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4408 - y1_output_loss: 0.1285 - y2_output_loss: 0.3170 - y1_output_root_mean_squared_error: 0.3567 - y2_output_root_mean_squared_error: 0.5600 - val_loss: 1.6506 - val_y1_output_loss: 0.2625 - val_y2_output_loss: 1.4571 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 1.1828
# Epoch 482/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4411 - y1_output_loss: 0.1318 - y2_output_loss: 0.3075 - y1_output_root_mean_squared_error: 0.3624 - y2_output_root_mean_squared_error: 0.5565 - val_loss: 0.9039 - val_y1_output_loss: 0.2405 - val_y2_output_loss: 0.6814 - val_y1_output_root_mean_squared_error: 0.4857 - val_y2_output_root_mean_squared_error: 0.8173
# Epoch 483/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5598 - y1_output_loss: 0.1318 - y2_output_loss: 0.4250 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.6539 - val_loss: 1.0674 - val_y1_output_loss: 0.2547 - val_y2_output_loss: 0.8424 - val_y1_output_root_mean_squared_error: 0.5028 - val_y2_output_root_mean_squared_error: 0.9025
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5881 - y1_output_loss: 0.1549 - y2_output_loss: 0.4317 - y1_output_root_mean_squared_error: 0.3944 - y2_output_root_mean_squared_error: 0.6577 - val_loss: 0.9668 - val_y1_output_loss: 0.2518 - val_y2_output_loss: 0.7416 - val_y1_output_root_mean_squared_error: 0.4999 - val_y2_output_root_mean_squared_error: 0.8467
# Epoch 485/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5641 - y1_output_loss: 0.1448 - y2_output_loss: 0.4152 - y1_output_root_mean_squared_error: 0.3821 - y2_output_root_mean_squared_error: 0.6466 - val_loss: 0.9745 - val_y1_output_loss: 0.2585 - val_y2_output_loss: 0.7343 - val_y1_output_root_mean_squared_error: 0.5003 - val_y2_output_root_mean_squared_error: 0.8510
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4760 - y1_output_loss: 0.1282 - y2_output_loss: 0.3495 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5901 - val_loss: 0.9618 - val_y1_output_loss: 0.2479 - val_y2_output_loss: 0.7369 - val_y1_output_root_mean_squared_error: 0.4794 - val_y2_output_root_mean_squared_error: 0.8556
# Epoch 487/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5095 - y1_output_loss: 0.1525 - y2_output_loss: 0.3528 - y1_output_root_mean_squared_error: 0.3924 - y2_output_root_mean_squared_error: 0.5963 - val_loss: 0.8663 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.6595 - val_y1_output_root_mean_squared_error: 0.4614 - val_y2_output_root_mean_squared_error: 0.8084
# Epoch 488/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3801 - y1_output_loss: 0.1125 - y2_output_loss: 0.2744 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.5189 - val_loss: 1.7924 - val_y1_output_loss: 0.4055 - val_y2_output_loss: 1.3543 - val_y1_output_root_mean_squared_error: 0.6432 - val_y2_output_root_mean_squared_error: 1.1742
# Epoch 489/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4272 - y1_output_loss: 0.1268 - y2_output_loss: 0.2988 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5472 - val_loss: 1.5872 - val_y1_output_loss: 0.2672 - val_y2_output_loss: 1.3306 - val_y1_output_root_mean_squared_error: 0.5208 - val_y2_output_root_mean_squared_error: 1.1471
# Epoch 490/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5977 - y1_output_loss: 0.1431 - y2_output_loss: 0.4492 - y1_output_root_mean_squared_error: 0.3798 - y2_output_root_mean_squared_error: 0.6733 - val_loss: 0.9266 - val_y1_output_loss: 0.2352 - val_y2_output_loss: 0.6936 - val_y1_output_root_mean_squared_error: 0.4843 - val_y2_output_root_mean_squared_error: 0.8319
# Epoch 491/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3377 - y1_output_loss: 0.1054 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3230 - y2_output_root_mean_squared_error: 0.4831 - val_loss: 1.5081 - val_y1_output_loss: 0.3000 - val_y2_output_loss: 1.2380 - val_y1_output_root_mean_squared_error: 0.5397 - val_y2_output_root_mean_squared_error: 1.1031
# Epoch 492/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5249 - y1_output_loss: 0.1365 - y2_output_loss: 0.3852 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.6224 - val_loss: 1.7709 - val_y1_output_loss: 0.5748 - val_y2_output_loss: 1.2961 - val_y1_output_root_mean_squared_error: 0.7160 - val_y2_output_root_mean_squared_error: 1.1217
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4773 - y1_output_loss: 0.1329 - y2_output_loss: 0.3404 - y1_output_root_mean_squared_error: 0.3656 - y2_output_root_mean_squared_error: 0.5862 - val_loss: 0.9179 - val_y1_output_loss: 0.2282 - val_y2_output_loss: 0.7074 - val_y1_output_root_mean_squared_error: 0.4723 - val_y2_output_root_mean_squared_error: 0.8336
# Epoch 494/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3435 - y1_output_loss: 0.0992 - y2_output_loss: 0.2415 - y1_output_root_mean_squared_error: 0.3162 - y2_output_root_mean_squared_error: 0.4935 - val_loss: 0.9150 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.7333 - val_y1_output_root_mean_squared_error: 0.4486 - val_y2_output_root_mean_squared_error: 0.8448
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3530 - y1_output_loss: 0.1017 - y2_output_loss: 0.2500 - y1_output_root_mean_squared_error: 0.3195 - y2_output_root_mean_squared_error: 0.5009 - val_loss: 0.9543 - val_y1_output_loss: 0.2152 - val_y2_output_loss: 0.7630 - val_y1_output_root_mean_squared_error: 0.4556 - val_y2_output_root_mean_squared_error: 0.8641
# Epoch 496/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4173 - y1_output_loss: 0.1085 - y2_output_loss: 0.3056 - y1_output_root_mean_squared_error: 0.3306 - y2_output_root_mean_squared_error: 0.5550 - val_loss: 0.8790 - val_y1_output_loss: 0.2125 - val_y2_output_loss: 0.6818 - val_y1_output_root_mean_squared_error: 0.4580 - val_y2_output_root_mean_squared_error: 0.8181
# Epoch 497/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4032 - y1_output_loss: 0.1067 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3280 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 1.1019 - val_y1_output_loss: 0.2703 - val_y2_output_loss: 0.8962 - val_y1_output_root_mean_squared_error: 0.4933 - val_y2_output_root_mean_squared_error: 0.9266
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.8298 - y1_output_loss: 0.1813 - y2_output_loss: 0.6461 - y1_output_root_mean_squared_error: 0.4254 - y2_output_root_mean_squared_error: 0.8055 - val_loss: 0.9110 - val_y1_output_loss: 0.2492 - val_y2_output_loss: 0.7057 - val_y1_output_root_mean_squared_error: 0.4714 - val_y2_output_root_mean_squared_error: 0.8300
# Epoch 499/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4929 - y1_output_loss: 0.1312 - y2_output_loss: 0.3573 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.6005 - val_loss: 0.8836 - val_y1_output_loss: 0.2150 - val_y2_output_loss: 0.6773 - val_y1_output_root_mean_squared_error: 0.4577 - val_y2_output_root_mean_squared_error: 0.8210
# Epoch 500/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3502 - y1_output_loss: 0.1094 - y2_output_loss: 0.2401 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.4904 - val_loss: 0.9536 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.7902 - val_y1_output_root_mean_squared_error: 0.4407 - val_y2_output_root_mean_squared_error: 0.8714

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("\nLoss = {}\nY1_loss = {}\nY1_mse = {}\nY2_loss = {}\nY2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 94us/sample - loss: 0.9536 - y1_output_loss: 0.1924 - y2_output_loss: 0.7497 - y1_output_root_mean_squared_error: 0.4407 - y2_output_root_mean_squared_error: 0.8714
#
# Loss = 0.9535513760207536
# Y1_loss = 0.19241181015968323
# Y1_mse = 0.44069790840148926
# Y2_loss = 0.7497413158416748
# Y2_mse = 0.8713992834091187

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
